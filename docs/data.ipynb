# %%
import glob

# %%
globg.glob("~/Downloads/ISCLS_camera_ready/*.pdf")
# Out:
# Running cells with 'newchat (Python 3.11.13)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/Users/mj/.pyenv/versions/newchat/bin/python -m pip install ipykernel -U --force-reinstall'
